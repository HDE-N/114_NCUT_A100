# %%
import subprocess
import time
import itertools
import os
import pandas as pd
import glob
from datetime import datetime

# ================= 設定區 =================
dic = {
    'batch_size': [1000],
    'epoch': [500],
    'layer': [2, 3, 4],
    'hidden': [16, 32, 64],
    'data_version': [48],
    'lr': [0.003, 0.001, 0.03, 0.01],
    'column': ['acceleration_X,acceleration_Y,acceleration_Z', 
               'gyroscope_X,gyroscope_Y,gyroscope_Z', 
               'acceleration_X,acceleration_Y,acceleration_Z,gyroscope_X,gyroscope_Y,gyroscope_Z'],
    'folds': [1, 2, 3, 4, 5],
}

MAX_CONCURRENT_JOBS = 20  
TRAIN_SCRIPT = "train_GRU_v28.py"
TEST_SCRIPT = "test_GRU_v28.py"
OUTPUT_LOG_DIR = "./test_log" # 測試結果存放的路徑
# =========================================

def get_combinations(params):
    keys = list(params.keys())
    values = list(params.values())
    for combo in itertools.product(*values):
        yield dict(zip(keys, combo))

def run_phase(phase_name, script_name, combinations, max_jobs):
    print(f"\n=== 開始執行階段: {phase_name} ===")
    total_jobs = len(combinations)
    running_processes = []
    
    for i, p in enumerate(combinations):
        cmd = [
            'python3', script_name,
            f'--batch_size={p["batch_size"]}',
            f'--epoch={p["epoch"]}',
            f'--layer={p["layer"]}',
            f'--hidden={p["hidden"]}',
            f'--data_version={p["data_version"]}',
            f'--lr={p["lr"]}',
            f'--column={p["column"]}',
            f'--fold={p["folds"]}'
        ]
        
        # 啟動程序
        proc = subprocess.Popen(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
        running_processes.append(proc)
        
        if i % 10 == 0:
            print(f"[{phase_name}] 進度: {i}/{total_jobs} (目前運行中: {len(running_processes)})")

        while len(running_processes) >= max_jobs:
            time.sleep(0.5)
            running_processes = [p for p in running_processes if p.poll() is None]

    for p in running_processes:
        p.wait()
    print(f"=== {phase_name} 階段完成 ===\n")

def collect_results():
    print("=== 正在從 ./test_log 彙整最新測試報告 ===")
    
    # 修改點：改為搜尋 test_log 資料夾下所有以 _result.csv 結尾的檔案
    result_files = glob.glob(os.path.join(OUTPUT_LOG_DIR, "*_result.csv"))
    
    if not result_files:
        print(f"在 {OUTPUT_LOG_DIR} 找不到任何測試結果檔案。")
        return

    all_dfs = []
    for f in result_files:
        try:
            # 讀取個別測試結果
            df = pd.read_csv(f)
            # 確保檔案不為空
            if not df.empty:
                all_dfs.append(df)
        except Exception as e:
            print(f"讀取 {f} 失敗: {e}")
    
    if all_dfs:
        # 合併所有結果
        final_df = pd.concat(all_dfs, ignore_index=True)
        
        # 根據 F1 Score 排序（最高分在前）
        final_df = final_df.sort_values(by="f1", ascending=False)
        
        # 輸出最終報告
        out_name = "Final_Report_540.csv"
        final_df.to_csv(out_name, index=False)
        
        print("-" * 30)
        print(f"報告整合完成！共匯總 {len(all_dfs)} 筆測試數據。")
        print(f"最終報告已產出: {out_name}")
        print("-" * 30)
        print("Top 5 最佳模型表現:")
        print(final_df.head(5)[['run_name', 'f1', 'acc', 'mAP']])
    else:
        print("沒有有效的數據可以合併。")

def main():
    start_time = datetime.now()
    combinations = list(get_combinations(dic))
    
    # 階段 2: 測試 (假設訓練已完成，直接執行測試)
    run_phase("Testing", TEST_SCRIPT, combinations, max_jobs=MAX_CONCURRENT_JOBS)
    
    # 階段 3: 彙整最新結果
    collect_results()

    end_time = datetime.now()
    print(f"\n全部任務完成！總耗時: {end_time - start_time}")

if __name__ == "__main__":
    main()
# Out:
# === 開始執行階段: Testing ===
# [Testing] 進度: 0/540 (目前運行中: 1)
# [Testing] 進度: 10/540 (目前運行中: 11)
# [Testing] 進度: 20/540 (目前運行中: 18)
# [Testing] 進度: 30/540 (目前運行中: 18)
# [Testing] 進度: 40/540 (目前運行中: 20)
# [Testing] 進度: 50/540 (目前運行中: 20)
# [Testing] 進度: 60/540 (目前運行中: 20)
# [Testing] 進度: 70/540 (目前運行中: 18)
# [Testing] 進度: 80/540 (目前運行中: 19)
# [Testing] 進度: 90/540 (目前運行中: 20)
# [Testing] 進度: 100/540 (目前運行中: 20)
# [Testing] 進度: 110/540 (目前運行中: 20)
# [Testing] 進度: 120/540 (目前運行中: 19)
# [Testing] 進度: 130/540 (目前運行中: 20)
# [Testing] 進度: 140/540 (目前運行中: 18)
# [Testing] 進度: 150/540 (目前運行中: 18)
# [Testing] 進度: 160/540 (目前運行中: 20)
# [Testing] 進度: 170/540 (目前運行中: 20)
# [Testing] 進度: 180/540 (目前運行中: 20)
# [Testing] 進度: 190/540 (目前運行中: 20)
# [Testing] 進度: 200/540 (目前運行中: 19)
# [Testing] 進度: 210/540 (目前運行中: 18)
# [Testing] 進度: 220/540 (目前運行中: 20)
# [Testing] 進度: 230/540 (目前運行中: 18)
# [Testing] 進度: 240/540 (目前運行中: 20)
# [Testing] 進度: 250/540 (目前運行中: 19)
# [Testing] 進度: 260/540 (目前運行中: 20)
# [Testing] 進度: 270/540 (目前運行中: 20)
# [Testing] 進度: 280/540 (目前運行中: 20)
# [Testing] 進度: 290/540 (目前運行中: 20)
# [Testing] 進度: 300/540 (目前運行中: 20)
# [Testing] 進度: 310/540 (目前運行中: 20)
# [Testing] 進度: 320/540 (目前運行中: 20)
# [Testing] 進度: 330/540 (目前運行中: 18)
# [Testing] 進度: 340/540 (目前運行中: 19)
# [Testing] 進度: 350/540 (目前運行中: 19)
# [Testing] 進度: 360/540 (目前運行中: 20)
# [Testing] 進度: 370/540 (目前運行中: 20)
# [Testing] 進度: 380/540 (目前運行中: 20)
# [Testing] 進度: 390/540 (目前運行中: 20)
# [Testing] 進度: 400/540 (目前運行中: 20)
# [Testing] 進度: 410/540 (目前運行中: 20)
# [Testing] 進度: 420/540 (目前運行中: 20)
# [Testing] 進度: 430/540 (目前運行中: 18)
# [Testing] 進度: 440/540 (目前運行中: 20)
# [Testing] 進度: 450/540 (目前運行中: 20)
# [Testing] 進度: 460/540 (目前運行中: 20)
# [Testing] 進度: 470/540 (目前運行中: 20)
# [Testing] 進度: 480/540 (目前運行中: 20)
# [Testing] 進度: 490/540 (目前運行中: 20)
# [Testing] 進度: 500/540 (目前運行中: 20)
# [Testing] 進度: 510/540 (目前運行中: 20)
# [Testing] 進度: 520/540 (目前運行中: 19)
# [Testing] 進度: 530/540 (目前運行中: 19)
# === Testing 階段完成 ===
#
# === 正在從 ./test_log 彙整最新測試報告 ===
# ------------------------------
# 報告整合完成！共匯總 540 筆測試數據。
# 最終報告已產出: Final_Report_540.csv
# ------------------------------
# Top 5 最佳模型表現:
#                                               run_name        f1       acc  \
# 38   fold5_layer_2_hidden_16_lr_0.03_dv_48_col_gyro...  0.790698  0.808511
# 533  fold4_layer_4_hidden_64_lr_0.01_dv_48_col_gyro...  0.782609  0.787234
# 405  fold5_layer_4_hidden_16_lr_0.03_dv_48_col_acce...  0.772727  0.787234
# 158  fold1_layer_2_hidden_64_lr_0.03_dv_48_col_gyro...  0.750000  0.744681
# 214  fold5_layer_3_hidden_16_lr_0.03_dv_48_col_gyro...  0.739130  0.744681
#
#           mAP
# 38   0.800113
# 533  0.586131
# 405  0.836610
# 158  0.750769
# 214  0.788569
#
# 全部任務完成！總耗時: 0:09:56.077166
